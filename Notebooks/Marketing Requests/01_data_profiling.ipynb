# %% [markdown]
# ### 1. Campaign Population
# - Reporting year: 2025
# - BusinessRule: campaign must start AND end within 2025
# - Expected: 64 campaigns

# %%
# %sql
SELECT COUNT(*) AS total_campaings, MIN(start_date) AS earlist_start_date, MAX(end_date) AS latest_end_date FROM `campaign&promotion`.gold.dim_campaign WHERE start_date >= DATE '2025-01-01' AND end_date <= DATE '2025-12-31';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_campaings</th><th>earlist_start_date</th><th>latest_end_date</th></tr></thead><tbody><tr><td>64</td><td>2025-01-01</td><td>2025-12-31</td></tr></tbody></table></div>

# %% [markdown]
# ### 2. Campaign Type Distribution

# %% [markdown]
# **Business View => What kind of campaigns did marketing actually run in 2025?**

# %%
# %sql
SELECT campaign_type, COUNT(*) AS campaign_count, SUM(budget) AS total_budget,
ROUND(AVG(budget),0) AS avg_budget
FROM `campaign&promotion`.gold.dim_campaign WHERE start_date >= DATE '2025-01-01' AND end_date <= DATE '2025-12-31'
GROUP BY campaign_type
ORDER BY campaign_count DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>campaign_type</th><th>campaign_count</th><th>total_budget</th><th>avg_budget</th></tr></thead><tbody><tr><td>Acquisition</td><td>15</td><td>1.6411E7</td><td>1094067.0</td></tr><tr><td>Engagement</td><td>12</td><td>8636000.0</td><td>719667.0</td></tr><tr><td>Seasonal</td><td>11</td><td>1.048E7</td><td>952727.0</td></tr><tr><td>Transaction Growth</td><td>10</td><td>6342000.0</td><td>634200.0</td></tr><tr><td>Referral</td><td>7</td><td>7689000.0</td><td>1098429.0</td></tr><tr><td>Merchant Promotion</td><td>6</td><td>5772000.0</td><td>962000.0</td></tr><tr><td>Reactivation</td><td>3</td><td>3726000.0</td><td>1242000.0</td></tr></tbody></table></div>

# %% [markdown]
# ### 3. Check campaign data validity

# %% [markdown]
# Expected : invalid_campaign_dates = 0

# %%
# %sql
SELECT
    COUNT(*) AS invalid_campaign_dates
FROM 
`campaign&promotion`.gold.dim_campaign
WHERE end_date < start_date;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>invalid_campaign_dates</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

# %% [markdown]
# ### 4. Check duplicate campaign IDs

# %% [markdown]
# Expected : zero rows

# %%
# %sql
SELECT
    campaign_id,
    COUNT(*) AS row_count
FROM `campaign&promotion`.gold.dim_campaign
GROUP BY campaign_id
HAVING row_count > 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>campaign_id</th><th>row_count</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### 5.Customer Profile

# %%
# %sql
SELECT 
    COUNT(*) AS customer_count,
    COUNT(DISTINCT customer_id) AS distinct_customers,
    MIN(registration_date) AS earliest_transaction,
    MAX(registration_date) AS latest_transaction
FROM `campaign&promotion`.gold.dim_customer
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_count</th><th>distinct_customers</th><th>earliest_transaction</th><th>latest_transaction</th></tr></thead><tbody><tr><td>30000</td><td>30000</td><td>2024-01-03</td><td>2026-03-28</td></tr></tbody></table></div>

# %%
# %sql
SELECT
    customer_segment,
    COUNT(*) AS customers,
    ROUND(
        100.0 * COUNT(*) / SUM(COUNT(*)) OVER (), 2
    ) AS customer_pct
FROM `campaign&promotion`.gold.dim_customer
GROUP BY customer_segment
ORDER BY customers DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_segment</th><th>customers</th><th>customer_pct</th></tr></thead><tbody><tr><td>Low Value</td><td>11011</td><td>36.70</td></tr><tr><td>Medium Value</td><td>9654</td><td>32.18</td></tr><tr><td>Dormant</td><td>4436</td><td>14.79</td></tr><tr><td>High Value</td><td>4425</td><td>14.75</td></tr><tr><td>New</td><td>474</td><td>1.58</td></tr></tbody></table></div>

# %% [markdown]
# ### 6. Transaction profile

# %%
# %sql
SELECT
    COUNT(*) AS total_transactions,
    COUNT(DISTINCT transaction_id) AS distinct_transactions,
    COUNT(DISTINCT customer_id) AS transacting_customers,
    SUM(CASE WHEN status = 'SUCCESS' THEN 1 ELSE 0 END) AS successful_transactions,
    SUM(CASE WHEN status <> 'SUCCESS' THEN 1 ELSE 0 END) AS unsuccessful_transactions,
    SUM(CASE WHEN status = 'SUCCESS' THEN amount ELSE 0 END) AS successful_transaction_value,
    SUM(CASE WHEN status = 'SUCCESS' THEN cashback ELSE 0 END) AS cashback
FROM `campaign&promotion`.gold.fct_transaction;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_transactions</th><th>distinct_transactions</th><th>transacting_customers</th><th>successful_transactions</th><th>unsuccessful_transactions</th><th>successful_transaction_value</th><th>cashback</th></tr></thead><tbody><tr><td>835143</td><td>835143</td><td>29174</td><td>780469</td><td>54674</td><td>4.700826886E10</td><td>9.1721765E7</td></tr></tbody></table></div>

# %% [markdown]
# ### 7. Participation profile

# %%
# %sql
SELECT
    COUNT(*) AS participation_records,
    COUNT(DISTINCT campaign_id) AS campaigns,
    COUNT(DISTINCT customer_id) AS customers,
    SUM(CASE WHEN eligible_flag THEN 1 ELSE 0 END) AS eligible_records,
    SUM(CASE WHEN participated_flag THEN 1 ELSE 0 END) AS participant_records
FROM `campaign&promotion`.gold.fct_campaign_participation;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>participation_records</th><th>campaigns</th><th>customers</th><th>eligible_records</th><th>participant_records</th></tr></thead><tbody><tr><td>179057</td><td>67</td><td>29103</td><td>179057</td><td>68691</td></tr></tbody></table></div>

# %% [markdown]
# ### 8. Redemption profile

# %%
# %sql
SELECT
    COUNT(*) AS redemption_count,
    COUNT(DISTINCT campaign_id) AS campaigns,
    COUNT(DISTINCT customer_id) AS customers,
    SUM(reward_amount) AS total_reward_cost,
    SUM(cashback_amount) AS total_cashback,
    SUM(discount_amount) AS total_discount
FROM `campaign&promotion`.gold.fct_promotion_redemption;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>redemption_count</th><th>campaigns</th><th>customers</th><th>total_reward_cost</th><th>total_cashback</th><th>total_discount</th></tr></thead><tbody><tr><td>61258</td><td>67</td><td>22768</td><td>2.0666312E8</td><td>9.1721765E7</td><td>1.08146E8</td></tr></tbody></table></div>
